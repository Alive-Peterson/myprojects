# %% [markdown]
# ### Financial Performance and Profitability Analysis

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('datasets/bss_sales_data.csv')
df.shape
# Out:
# (140690, 20)

# %%
df.isnull().sum()
# Out:
# sku                           433
# salesdate                     433
# price                         433
# unitsordered                  433
# sales                         433
# cogs                          433
# fba                           433
# reffee                        433
# adspend                       433
# profit                        433
# comp_1_price                50299
# comp_2_price                85411
# comp_3_price               116972
# comp_4_price               132411
# comp_5_price               138654
# comp_data_min_price         43121
# comp_data_max_price         43121
# managed_fba_stock_level     24740
# min_price                     433
# max_price                     433
# dtype: int64

# %%
df = df.dropna(how='all').copy()

# %%
df.shape
# Out:
# (140257, 20)

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# comp_5_price               138221
# comp_4_price               131978
# comp_3_price               116539
# comp_2_price                84978
# comp_1_price                49866
# comp_data_min_price         42688
# comp_data_max_price         42688
# managed_fba_stock_level     24307
# unitsordered                    0
# price                           0
# salesdate                       0
# sku                             0
# adspend                         0
# profit                          0
# fba                             0
# reffee                          0
# cogs                            0
# sales                           0
# min_price                       0
# max_price                       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df[['sku', 'salesdate']].duplicated().sum()
# Out:
# np.int64(596)
